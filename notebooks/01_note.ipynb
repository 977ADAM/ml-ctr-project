# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/dataset.csv")

# %%
df.head()
# Out:
#    ID кампании  ID баннера  Тип баннера Тип устройства  Показы  Переходы  \
# 0      3405596    15262577  interactive      Компьютер   12596        27
# 1      3405596    15257617  interactive       Смартфон    9812        30
# 2      3405596    15257617  interactive        Планшет     224         2
# 3      3405596    15262577  interactive      Компьютер   12511        25
# 4      3405596    15257617  interactive       Смартфон    9822        38
#
#       CTR
# 0  0.2144
# 1  0.3057
# 2  0.8929
# 3  0.1998
# 4  0.3869

# %%
df['CTR'] = np.where(df['Переходы'] > 0, df['Переходы'] / df['Показы'], 0).round(6)

# %%
df.head()
# Out:
#    ID кампании  ID баннера  Тип баннера Тип устройства  Показы  Переходы  \
# 0      3405596    15262577  interactive      Компьютер   12596        27
# 1      3405596    15257617  interactive       Смартфон    9812        30
# 2      3405596    15257617  interactive        Планшет     224         2
# 3      3405596    15262577  interactive      Компьютер   12511        25
# 4      3405596    15257617  interactive       Смартфон    9822        38
#
#         CTR
# 0  0.002144
# 1  0.003057
# 2  0.008929
# 3  0.001998
# 4  0.003869

# %%
df.to_csv('dataset.csv')
