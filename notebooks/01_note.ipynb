# %%
import pandas as pd
import numpy as np


df = pd.read_csv("../data/dataset.csv")

# %%
def prepare_targets(df: pd.DataFrame, impr_col, click_col):
    impr = df[impr_col]
    clicks = df[click_col]

    # базовые проверки (лучше держать включёнными)
    if impr <= 0:
        raise ValueError("Найдены строки с Показы <= 0 — их нужно удалить/исправить.")
    if clicks < 0 or clicks > impr:
        raise ValueError("Найдены некорректные Переходы (clicks) относительно Показы (impr).")
    return clicks, impr

# %%
clicks, impr = prepare_targets(df, "Показы", "Переходы")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 clicks, impr = prepare_targets(df, "Показы", "Переходы")
#
# Cell In[2], line 7, in prepare_targets(df, impr_col, click_col)
#       5 # базовые проверки (лучше держать включёнными)
#       6 if np.any(impr <= 0):
# ----> 7     raise ValueError("Найдены строки с Показы <= 0 — их нужно удалить/исправить.")
#       8 if np.any(clicks < 0) or np.any(clicks > impr):
#       9     raise ValueError("Найдены некорректные Переходы (clicks) относительно Показы (impr).")
#
# ValueError: Найдены строки с Показы <= 0 — их нужно удалить/исправить.
